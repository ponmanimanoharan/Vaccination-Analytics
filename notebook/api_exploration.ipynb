# %%
import sys
import os

# %%
sys.path.append(os.path.abspath('/Github/Vaccination-Analytics/scripts'))

# %%
from fetch_api_data import fetch_to_df

# %%
df_list = fetch_to_df()
# Out:
# fullv
# mslv
# bcgv
# dptv
# PCV3
# poliov
# ROTAC
# SDGHPVRECEIVED
# WHS4_100
# WHS4_129
# WHS4_117
# WHS4_544
# WHS4_543
# WHS8_110
# vbcg
# vfull
# vdpt
# MCV2
# vmsl
# vpolio

# %%
for x in df_list:
    if not x.empty:
        print(x["IndicatorCode"].unique())
        print(x.columns)
        print("\n")
# Out:
# ['PCV3']
# Index(['Id', 'IndicatorCode', 'SpatialDimType', 'SpatialDim',
#        'ParentLocationCode', 'TimeDimType', 'ParentLocation', 'Dim1Type',
#        'Dim1', 'TimeDim', 'Dim2Type', 'Dim2', 'Dim3Type', 'Dim3',
#        'DataSourceDimType', 'DataSourceDim', 'Value', 'NumericValue', 'Low',
#        'High', 'Comments', 'Date', 'TimeDimensionValue', 'TimeDimensionBegin',
#        'TimeDimensionEnd'],
#       dtype='object')
#
#
# ['ROTAC']
# Index(['Id', 'IndicatorCode', 'SpatialDimType', 'SpatialDim', 'TimeDimType',
#        'ParentLocationCode', 'ParentLocation', 'Dim1Type', 'TimeDim', 'Dim1',
#        'Dim2Type', 'Dim2', 'Dim3Type', 'Dim3', 'DataSourceDimType',
#        'DataSourceDim', 'Value', 'NumericValue', 'Low', 'High', 'Comments',
#        'Date', 'TimeDimensionValue', 'TimeDimensionBegin', 'TimeDimensionEnd'],
#       dtype='object')
#
#
# ['SDGHPVRECEIVED']
# Index(['Id', 'IndicatorCode', 'SpatialDimType', 'SpatialDim',
# ...

# %%
final_dataset = pd.concat(df_list, ignore_index=True)

# %%
final_dataset
# Out:
#              Id IndicatorCode SpatialDimType SpatialDim ParentLocationCode  \
# 0       7724552          PCV3        COUNTRY        DZA                AFR
# 1       6169371          PCV3         REGION        EMR               None
# 2       6189205          PCV3        COUNTRY        PAK                EMR
# 3       1068132          PCV3        COUNTRY        MOZ                AFR
# 4       8819551          PCV3        COUNTRY        MLI                AFR
# ...         ...           ...            ...        ...                ...
# 109220  9424844        vpolio        COUNTRY        GHA                AFR
# 109221  9425247        vpolio        COUNTRY        HTI                AMR
# 109222  9425467        vpolio        COUNTRY        ALB                EUR
# 109223  9426259        vpolio        COUNTRY        GHA                AFR
# 109224  9426303        vpolio        COUNTRY        CAF                AFR
#
#        TimeDimType         ParentLocation           Dim1Type  \
# ...
